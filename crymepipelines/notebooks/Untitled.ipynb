# %%
import os
import sys

try:
    import pyspark
except ImportError:
    import findspark
    findspark.init()
    import pyspark
    
    
# give notebook access to crymepipelines app modules
CRYMEPIPELINES_PATH = '/home/ben/.envs/cc/CrymeClarity/crymepipelines/src'
sys.path.insert(0, CRYMEPIPELINES_PATH)

#build spark session
APP_NAME = 'CRYME_PIPELINE_DEV'
sc = pyspark.SparkContext()
spark = pyspark.sql.SparkSession(sc).builder.appName(APP_NAME).getOrCreate()

# %%
# import cyrmepipelines app modules
import csv
from datetime import datetime, timedelta
import os
import pickle as p
import shutil

from shared.objects.samples import SamplesManager
from shared.settings import CF_TRUST_DELAY, START_DATE, cf_conn, cp_conn, TMP_DIR, BIN_DIR
from tasks.base import SparkCrymeTask, NativeCrymeTask
from utils import crime_occ_udf, ts_to_minutes_in_day_udf, ts_to_hour_of_day_udf, ts_to_day_of_week_udf, ts_conv, safety_rel_crimes
from tasks.mixins import SearchForCrimesMixin

# %%
crime_incidents = spark.read.parquet(CRYMEPIPELINES_PATH+'/tmp/clean_crime_incidents.parquet')
crime_incidents = crime_incidents.filter(crime_incidents.date_occ > datetime.now().date() - timedelta(days=30))

# %%
by_type = crime_incidents.groupBy('premis_desc').agg({'_id': 'count'}).orderBy("count(_id)", ascending=False)
by_type.show(by_type.count(), False)
# Out:
# +---------------------------------------------------------+----------+
# |premis_desc                                              |count(_id)|
# +---------------------------------------------------------+----------+
# |STREET                                                   |2011      |
# |SINGLE FAMILY DWELLING                                   |1039      |
# |MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             |772       |
# |PARKING LOT                                              |600       |
# |SIDEWALK                                                 |433       |
# |VEHICLE, PASSENGER/TRUCK                                 |314       |
# |OTHER BUSINESS                                           |293       |
# |DRIVEWAY                                                 |154       |
# |GARAGE/CARPORT                                           |140       |
# |RESTAURANT/FAST FOOD                                     |118       |
# |PARKING UNDERGROUND/BUILDING                             |75        |
# |MARKET                                                   |71        |
# |ALLEY                                                    |67        |
# |PARK/PLAYGROUND                                          |60        |
# |YARD (RESIDENTIAL/BUSINESS)                              |53        |
# |HOTEL                                                    |47        |
# |DRUG STORE                                               |34        |
# |OTHER PREMISE                                            |34        |
# |OTHER STORE                                              |33        |
# |GAS STATION                                              |32        |
# |MINI-MART                                                |29        |
# |TRANSPORTATION FACILITY (AIRPORT)                        |25        |
# |DEPARTMENT STORE                                         |24        |
# |HOSPITAL                                                 |24        |
# |MTA BUS                                                  |24        |
# |HEALTH SPA/GYM                                           |23        |
# |CONSTRUCTION SITE                                        |22        |
# |BUS STOP                                                 |21        |
# |LA UNION STATION (NOT LINE SPECIFIC)                     |20        |
# |NURSING/CONVALESCENT/RETIREMENT HOME                     |19        |
# |JUNIOR HIGH SCHOOL                                       |19        |
# |COFFEE SHOP (STARBUCKS, COFFEE BEAN, PEET'S, ETC.)       |19        |
# |MOTEL                                                    |18        |
# |CONDOMINIUM/TOWNHOUSE                                    |17        |
# |OFFICE BUILDING/OFFICE                                   |17        |
# |COLLEGE/JUNIOR COLLEGE/UNIVERSITY                        |17        |
# |LIQUOR STORE                                             |17        |
# |OTHER RESIDENCE                                          |17        |
# |PORCH, RESIDENTIAL                                       |15        |
# |BAR/COCKTAIL/NIGHTCLUB                                   |15        |
# |HIGH SCHOOL                                              |15        |
# |MISSIONS/SHELTERS                                        |13        |
# |BEAUTY/BARBER SHOP                                       |12        |
# |OTHER/OUTSIDE                                            |12        |
# |PUBLIC STORAGE                                           |12        |
# |SHOPPING MALL (COMMON AREA)                              |12        |
# |LAUNDROMAT                                               |11        |
# |DISCOUNT STORE (99 CENT,DOLLAR,ETC.                      |11        |
# |NIGHT CLUB (OPEN EVENINGS ONLY)                          |11        |
# |ELEMENTARY SCHOOL                                        |11        |
# |CLOTHING STORE                                           |11        |
# |CELL PHONE STORE                                         |10        |
# |LIBRARY                                                  |10        |
# |BEACH                                                    |10        |
# |POLICE FACILITY                                          |9         |
# |AUTO REPAIR SHOP                                         |8         |
# |GROUP HOME                                               |8         |
# |BAR/SPORTS BAR (OPEN DAY & NIGHT)                        |8         |
# |THEATRE/MOVIE                                            |8         |
# |STUDIO (FILM/PHOTOGRAPHIC/MUSIC)                         |8         |
# |CHURCH/CHAPEL (CHANGED 03-03 FROM CHURCH/TEMPLE)         |7         |
# |MEDICAL/DENTAL OFFICES                                   |7         |
# |STAPLES CENTER *                                         |7         |
# |MASSAGE PARLOR                                           |6         |
# |TOBACCO SHOP                                             |6         |
# |GOVERNMENT FACILITY (FEDERAL,STATE, COUNTY & CITY)       |6         |
# |DODGER STADIUM                                           |6         |
# |DIY CENTER (LOWE'S,HOME DEPOT,OSH,CONTRACTORS WAREHOUSE) |6         |
# |BANK                                                     |6         |
# |THE GROVE                                                |6         |
# |WAREHOUSE                                                |6         |
# |SPECIALTY SCHOOL/OTHER                                   |6         |
# |ABANDONED BUILDING ABANDONED HOUSE                       |5         |
# |AUTOMATED TELLER MACHINE (ATM)                           |5         |
# |STORAGE SHED                                             |5         |
# |CAR WASH                                                 |5         |
# |TOW YARD*                                                |5         |
# |POST OFFICE                                              |5         |
# |MTA - RED LINE - HOLLYWOOD/HIGHLAND                      |5         |
# |CATERING/ICE CREAM TRUCK                                 |5         |
# |MTA - RED LINE - HOLLYWOOD/VINE                          |5         |
# |TRAIN DEPOT/TERMINAL, OTHER THAN MTA                     |4         |
# |MEDICAL MARIJUANA FACILITIES/BUSINESSES                  |4         |
# |PROJECT/TENEMENT/PUBLIC HOUSING                          |4         |
# |BEAUTY SUPPLY STORE                                      |4         |
# |TRANSITIONAL HOUSING/HALFWAY HOUSE                       |4         |
# |null                                                     |4         |
# |MEMBERSHIP STORE (COSTCO,SAMS CLUB)*                     |4         |
# |SWAP MEET                                                |3         |
# |AUTO SUPPLY STORE*                                       |3         |
# |NURSERY/FLOWER SHOP                                      |3         |
# |AUTO DEALERSHIP (CHEVY, FORD, BMW, MERCEDES, ETC.)       |3         |
# |BUS-CHARTER/PRIVATE                                      |3         |
# |BASKETBALL COURTS                                        |3         |
# |METROLINK TRAIN                                          |3         |
# |OTHER RR TRAIN (UNION PAC, SANTE FE ETC                  |3         |
# |VACANT LOT                                               |3         |
# |MTA - EXPO LINE - EXPO/CRENSHAW                          |2         |
# |TRAIN, OTHER THAN MTA (ALSO QUERY 809/810/811)           |2         |
# |ELECTRONICS STORE (IE:RADIO SHACK, ETC.)                 |2         |
# |THE BEVERLY CENTER                                       |2         |
# |MTA - EXPO LINE - FARMDALE                               |2         |
# |THE BEVERLY CONNECTION                                   |2         |
# |MTA - GOLD LINE - PICO/ALISO                             |2         |
# |BUS, SCHOOL, CHURCH                                      |2         |
# |MTA - EXPO LINE - 7TH AND METRO CENTER                   |2         |
# |SINGLE RESIDENCE OCCUPANCY (SRO'S) LOCATIONS             |2         |
# |TRANSIENT ENCAMPMENT                                     |2         |
# |DETENTION/JAIL FACILITY                                  |2         |
# |MTA - RED LINE - VERMONT/SANTA MONICA                    |2         |
# |MTA - EXPO LINE - EXPO/WESTERN                           |2         |
# |MTA - GREEN LINE - AVALON                                |2         |
# |7TH AND METRO CENTER (NOT LINE SPECIFIC)                 |2         |
# |VALET                                                    |2         |
# |MOBILE HOME/TRAILERS/CONSTRUCTION TRAILERS/RV'S/MOTORHOME|2         |
# |MTA - RED LINE - NORTH HOLLYWOOD                         |2         |
# |MTA - RED LINE - VERMONT/BEVERLY                         |2         |
# |PHARMACY INSIDE STORE OR SUPERMARKET*                    |2         |
# |BALCONY*                                                 |2         |
# |MTA - GOLD LINE - SOUTHWEST MUSEUM                       |2         |
# |FREEWAY                                                  |2         |
# |SPORTS VENUE, OTHER                                      |2         |
# |MTA - EXPO LINE - EXPO/BUNDY                             |2         |
# |TRAIN TRACKS                                             |2         |
# |PATIO*                                                   |2         |
# |TRADE SCHOOL (MEDICAL-TECHNICAL-BUSINESS)*               |2         |
# |JEWELRY STORE                                            |2         |
# |RECYCLING CENTER                                         |2         |
# |HANDBALL COURTS                                          |1         |
# |EQUIPMENT RENTAL                                         |1         |
# |DELIVERY SERVICE (FED EX, UPS, COURIERS,COURIER SERVICE)*|1         |
# |MTA - RED LINE - UNIVERSAL CITY/STUDIO CITY              |1         |
# |CHECK CASHING*                                           |1         |
# |TV/RADIO/APPLIANCE                                       |1         |
# |MTA - EXPO LINE - EXPO PARK/USC                          |1         |
# |MTA - RED LINE - WILSHIRE/VERMONT                        |1         |
# |ELEVATOR                                                 |1         |
# |AUTO SALES LOT                                           |1         |
# |POOL-PUBLIC/OUTDOOR OR INDOOR*                           |1         |
# |MTA - PURPLE LINE - PERSHING SQUARE                      |1         |
# |NAIL SALON                                               |1         |
# |VETERINARIAN/ANIMAL HOSPITAL                             |1         |
# |SKATING RINK*                                            |1         |
# |MTA - GREEN LINE - HARBOR FWY                            |1         |
# |MTA - EXPO LINE - EXPO/LA BREA                           |1         |
# |MTA PROPERTY OR PARKING LOT                              |1         |
# |PUBLIC RESTROOM/OUTSIDE*                                 |1         |
# |BUS STOP/LAYOVER (ALSO QUERY 124)                        |1         |
# |PUBLIC RESTROOM(INDOORS-INSIDE)                          |1         |
# |MTA - RED LINE - 7TH AND METRO CENTER                    |1         |
# |MTA - ORANGE LINE - CANOGA                               |1         |
# |PRIVATE SCHOOL/PRESCHOOL                                 |1         |
# |MTA - ORANGE LINE - VAN NUYS                             |1         |
# |MTA - PURPLE LINE - WESTLAKE/MACARTHUR PARK              |1         |
# |BUS DEPOT/TERMINAL, OTHER THAN MTA                       |1         |
# |MTA - RED LINE - WESTLAKE/MACARTHUR PARK                 |1         |
# |MTA - BLUE LINE - 7TH AND METRO CENTER                   |1         |
# |MTA - GOLD LINE - HERITAGE SQ                            |1         |
# |MTA - EXPO LINE - EXPO/VERMONT                           |1         |
# |MAIL BOX                                                 |1         |
# |TOOL SHED*                                               |1         |
# |MTA - RED LINE - UNION STATION                           |1         |
# |MTA - BLUE LINE - 103RD/WATTS TOWERS                     |1         |
# |SHORT-TERM VACATION RENTAL                               |1         |
# +---------------------------------------------------------+----------+
